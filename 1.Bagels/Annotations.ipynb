# %% [markdown]
# # Index:
# ## Part 1: The code itself
# ## Part 2: What are the main functions?
# 1. Constants declared at the top
# 2. main()
# 3. getSecretNum()
# 4. getClues()
# 5. Run main function when not imported
#
# ## Part 3: What are the main loops?
# #####  Main Function Loops
#     1. While (the game is running)
#         1. While (you still have guesses left)
#             1. While (you type in an answer in the incorrect format)
#             2. If (your guess is completely right)
#             3. If (you run out of guesses)
#         2. If (you want to play again Y/N)
#     2. Print('thanks for playing')
#
#
# ##### getSecretNum Loops
#     1. For (the amount of numbers to grab)
#
#
#  ##### getClues Loops
#     1. If (your guess is the secret number)
#     2. For (every index value in the range of the length of the guess)
#         1. If (that index value's number is equal to a number in the same index position as the secret answer)
#         2. Elif (that index value's number is in the secret answer, but not necessarily in the same position)
#     3. If (you havent gotten any of them right)
#     4. Else (scramble the clue order)
#
#
#
# ## Part 4: Lines of code I'd like to understand better
#
#
#
#
# ## Part 5: A step by step guide on how this game runs through the code:

# %% [markdown]
# # Part 1: The Original Code

# %%
'''This simple game was made using a tutorial in "The Big Book of Small Python projects
by Al Swiegart. In this game you guess a number based on clues'''

import random

NUM_DIGITS= 3 #set this to higher numbers to make this game harder and harder
MAX_GUESSES = 10 #More or less guesses for the user, self explanatory

def main(): #I've discovered that 'main' is usually autoatically executed by a program whenever it starts up, i dont know if python does that but we'll find out
    print('''Bagels, a deductive logic game made by Al Swiegart
    
    I am thinking of a {}-digit number with no repeated digits. Try to guess what it is. Here are some clues:
    When I say:     That means:
    Pico            One digit is correct but in the wrong position.
    Fermi           One digit is correct AND in the right position.
    Bagels          No digit is correct.
    
    For example, if the secret number was 248 and your guess was 843, the clues would be Fermi Pico.'''.format(NUM_DIGITS)) #Oh cool, so by putting .format(string) outside the print statement, i can make it automatically slap that string inside the {}

    while True: #Main game loop.
        secretNum = getSecretNum()
        print('I have thought of a number.')
        print(' You have {} guesses to get it right.'.format(MAX_GUESSES))

        numGuesses = 1
        while numGuesses <= MAX_GUESSES:
            guess = ''
            #Keep looping till a valid guess is entered
            while len(guess) != NUM_DIGITS or not guess.isdecimal():
                print('Guess #{}: '.format(numGuesses))
                guess = input('> ')

            clues = getClues(guess, secretNum)
            print(clues)
            numGuesses += 1

            if guess == secretNum:
                break #They got it right, so break out of the loop
            if numGuesses > MAX_GUESSES:
                print("Sorry chief, you rant out of guesses")
                print("The right answer was{}".format(secretNum))

        #Ask player if they want to play again
        print("Wann play again? (yes or no)")
        if not input('> ').lower().startswith('y'):
            break
    print('Thanks for playing!')


def getSecretNum():
    """Returns a string made up of NUM_DIGITS unique random digits."""
    numbers = list("0123456789")
    random.shuffle(numbers) #woah holy crap. so he achieved this by making a list of all digits, randomizing it, and then picking the first X number of digits from the list. I was wondering how he would prevent the program from selecting duplicate numbers.

    # Get the first NUM_DIGITS in the list for the secret number
    secretNum = ''
    for i in range(NUM_DIGITS):
        secretNum += str(numbers[i])
    return secretNum


def getClues(guess, secretNum):
    #This returns a string with the pico, fermi, bagels clues.
    if guess == secretNum:
        return 'You got it!'

    clues = []

    for i in range(len(guess)):
        if guess[i] == secretNum[i]:
            #A correct digit is in the correct place.
            clues.append('Fermi')
        elif guess[i] in secretNum:
            #A correct clue is in an incorrect place.
            clues.append('Pico')
    if len(clues) == 0:
        return 'Bagels' #No correct digits at all
    else:
        #sort the clues into alphabetical order so the order doesnt give it away
        clues.sort()
        #make a single string from the list of string clues.
        return ' '.join(clues)


#If the program is run instead of being imported, run the game:
if __name__ == '__main__':
    main()

# %% [markdown]
# # Part 2: The Main Functions
# ## The Constants declared at the top
# ## Main()
# ## GetSecretNum()
# ## GetClues()
# ## Running if not imported

# %% [markdown]
# # Part 3: The Main Loops
#
# #####  Main Function Loops
#     Tell the user about the game
#     Tell them how long the Secret answer is
#
#     set Guesses = 1
#
#     1. While (the game is running)
#
#         Run SecretNumber() and save it
#         Tell the user how many guesses they have
#
#         1. While (you still have guesses left)
#
#             guesses = empty
#
#             1. While (you type in an answer in the incorrect format, or during the first loop, since guesses is empty initially)
#
#                 Tell the user what attempt # theyre on
#                 ask for a guess
#
#             Run GetClues(pass through guess, and the secret number)
#             Tell them the clues
#             Add +1 to the number of times theyve guessed
#
#             2. If (your guess is completely right)
#
#                 break out of this loop
#
#             3. If (you run out of guesses)
#                 Tell them 'sorry you ran out of guesses'
#                 The correct answer was (secret answer)
#         2. If (you want to play again Y/N)
#     2. Print('thanks for playing')
#
#
# ##### getSecretNum Loops
#     Make a list of numbers
#     Shuffle that list of numbers
#
#     secretnumber = blank/ready
#     1. For (the amount of numbers to grab)
#         loop through and add +1 number to the string secretnumber
#         will loop through NUM_DIGITS times
#     return secretnumber
#
#
#  ##### getClues Loops
#     1. If (your guess is the secret number)
#
#         return 'you got it!'
#     make a blank [list] called clues
#     2. For (every index value in the range of the length of the guess)
#
#         1. If (that index value's number is equal to a number in the same index position as the secret answer)
#
#             append 'Fermi" to the end of the list [clues]
#
#         2. Elif (that index value's number is in the secret answer, but not necessarily in the same position)
#
#             append [pico] to the end of the list of clues
#
#     3. If (you havent gotten any of them right)
#
#         return 'bagels'
#
#     4. Else (scramble the clue order)
#
#         sort [clues] into alphabetical order
#
#         return [clues] joined together with a space inbetween each

# %% [markdown]
# # Part 4: Lines of code I'd like to understand better
# line 52: numbers = list("0123456789")
# line 57: for i in range(NUM_DIGITS)
# line 58: secretNum += str(numbers[i])

# %% [markdown]
# # Part 5: A step-by-step Walkthrough of the Code
